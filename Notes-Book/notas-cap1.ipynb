# %% [markdown]
# # Notas rápidas en funcion del libro
# Estas son notas rápidas, de resumen, ayuda-memoria, etc. Para tenrer y conservar a lo largo de este repositorio. Particularmente del capitulo 1 del libro, antes de ir puliendo como corresponde las cosas.
